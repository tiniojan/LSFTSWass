# %% [markdown]
# # SST

# %%
from models.GaussianSmoothed_SST import main
main()
# Out:
# Best bandwidths found: {np.float64(0.1): {np.int64(7): 0.762323260307312, np.int64(21): 0.762323260307312, np.int64(35): 0.762323260307312}, np.float64(0.01): {np.int64(7): 0.762323260307312, np.int64(21): 0.762323260307312, np.int64(35): 0.762323260307312}, np.float64(0.001): {np.int64(7): 0.762323260307312, np.int64(21): 0.762323260307312, np.int64(35): 0.762323260307312}, np.float64(0.0001): {np.int64(7): 0.762323260307312, np.int64(21): 0.762323260307312, np.int64(35): 0.762323260307312}}
# ----------------------------------------------------------------------------------------------------
# Running Wasserstein distances for σ=0.1, j=7 at 2025-04-09 17:53:56.347203 ...
# Wasserstein distances finished at 2025-04-09 17:53:56.362828; time elapsed = 0:00:00.015625.
# ----------------------------------------------------------------------------------------------------
# Running Wasserstein distances for σ=0.1, j=21 at 2025-04-09 17:53:56.362828 ...
# ...
