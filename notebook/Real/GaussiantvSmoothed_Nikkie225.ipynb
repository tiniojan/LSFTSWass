# %% [markdown]
# # Nikkie225

# %%
from models.GaussianSmoothed_Nikkie225 import main
main()
# Out:
# Best bandwidths found: {np.float64(0.1): {np.int64(10): 0.009999999776482582, np.int64(30): 0.009999999776482582, np.int64(50): 0.009999999776482582}, np.float64(0.01): {np.int64(10): 0.009999999776482582, np.int64(30): 0.009999999776482582, np.int64(50): 0.009999999776482582}, np.float64(0.001): {np.int64(10): 0.009999999776482582, np.int64(30): 0.009999999776482582, np.int64(50): 0.009999999776482582}, np.float64(0.0001): {np.int64(10): 0.009999999776482582, np.int64(30): 0.009999999776482582, np.int64(50): 0.009999999776482582}}
# ----------------------------------------------------------------------------------------------------
# Running Wasserstein distances for σ=0.1, j=10 at 2025-04-09 18:07:16.753107 ...
# Wasserstein distances finished at 2025-04-09 18:07:17.151379; time elapsed = 0:00:00.398272.
# ----------------------------------------------------------------------------------------------------
# ...
