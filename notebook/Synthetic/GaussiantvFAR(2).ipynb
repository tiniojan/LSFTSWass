# %% [markdown]
# # Gaussian tvFAR(2)

# %%
from models.GaussiantvFAR2 import main
main()
# Out:
# ----------------------------------------------------------------------------------------------------
# Simulation of L-replications with T-samples of process ...
# Montecarlo 1 completed.
# Simulation completed; time elapsed = 0:00:05.887910.
# ----------------------------------------------------------------------------------------------------
# Running computation weights for Montecarlo 1 starts at 2025-04-09 17:58:14.606009 ...
# Weights computation complete for Montecarlo 1 at 2025-04-09 17:58:14.822327; time elapsed = 0:00:00.216318.
# ----------------------------------------------------------------------------------------------------
# Running wasserstein distances starts at 2025-04-09 17:58:14.858370 ...
# Wasserstein distances at 2025-04-09 17:58:15.005493; time elapsed = 0:00:00.147123.
