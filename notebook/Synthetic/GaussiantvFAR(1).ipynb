# %% [markdown]
# # Gaussian tvFAR(1)

# %%
from models.GaussiantvFAR1 import main
main()
# Out:
# ----------------------------------------------------------------------------------------------------
# Simulation of L-replications with T-samples of process ...
# Montecarlo 1 completed.
# Simulation completed; time elapsed = 0:00:04.137433.
# ----------------------------------------------------------------------------------------------------
# Running computation weights for Montecarlo 1 starts at 2025-04-09 17:46:23.922626 ...
# Weights computation complete for Montecarlo 1 at 2025-04-09 17:46:24.233176; time elapsed = 0:00:00.310550.
# ----------------------------------------------------------------------------------------------------
# Running wasserstein distances starts at 2025-04-09 17:46:24.261154 ...
# Wasserstein distances at 2025-04-09 17:46:24.459368; time elapsed = 0:00:00.198214.
